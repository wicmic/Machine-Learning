# %% [markdown]
# # k-Nearest Neighbour

# %%
import pandas as pd

df = pd.read_csv("data/classification.csv")

# Ein paar Spalten vorab aus den Daten entfernen geht so:
# df = df.drop("Spaltenname", axis = 1)

# Eine kategorische Variable in mehrere Spalten umwandeln (One Hot Encoding) geht so:
# df = pd.get_dummies(df, columns = ["Spaltenname"])

len(df)
# Out:
# 297

# %%
from sklearn.model_selection import train_test_split

# Welche Spalten sollen zur Vorhersage verwendet werden
X = df[["age", "interest"]].values

# Oder: Die Spalte "success" soll nicht zur Vorhersage verwendet werden:
# X = df.drop("success", axis = 1).values

y = df["success"].values

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 0, test_size = 0.25)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
# Mehrere Werte n_neighbors ausprobieren!!!
model = KNeighborsClassifier(n_neighbors =19)
model.fit(X_train, y_train)
print(model.score(X_test, y_test))
# Out:
# 0.96

# %%
import numpy as np
for i in np.arange(1,41,2):
    model = KNeighborsClassifier(n_neighbors =i)
    model.fit(X_train, y_train)
    print("i:", i, " score:", model.score(X_test, y_test))
# Out:
# i: 1  score: 0.8933333333333333
# i: 3  score: 0.92
# i: 5  score: 0.9466666666666667
# i: 7  score: 0.9466666666666667
# i: 9  score: 0.9466666666666667
# i: 11  score: 0.9466666666666667
# i: 13  score: 0.9466666666666667
# i: 15  score: 0.9466666666666667
# i: 17  score: 0.9466666666666667
# i: 19  score: 0.96
# i: 21  score: 0.9466666666666667
# i: 23  score: 0.9466666666666667
# i: 25  score: 0.9466666666666667
# i: 27  score: 0.9466666666666667
# i: 29  score: 0.9466666666666667
# i: 31  score: 0.96
# i: 33  score: 0.9466666666666667
# i: 35  score: 0.92
# i: 37  score: 0.92
# i: 39  score: 0.92

# %%
# Hinweis: Damit dieser Befehl funktioniert, muss die 
# "helper.py" - Datei im selben Ordner liegen, wie das
# aktuelle Jupyter Notebook

from helper import plot_classifier

# Trainings-Daten plotten
plot_classifier(model, X_train, y_train, proba = True, xlabel = "Alter", ylabel = "Interesse")

# %%
# Testdaten plotten
plot_classifier(model, X_test, y_test, proba = True, xlabel = "Alter", ylabel = "Interesse")
