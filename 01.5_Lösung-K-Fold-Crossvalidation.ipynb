# %%
import pandas as pd

df = pd.read_csv("../diamonds.csv")

df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
X = df[["carat"]].values
Y = df[["price"]].values

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
#from sklearn.model_selection import KFold
from sklearn.model_selection import RepeatedKFold

import numpy as np
#scores = cross_val_score(LinearRegression(), X, Y, cv = KFold())
scores = cross_val_score(LinearRegression(), X, Y, cv = RepeatedKFold(n_repeats = 10))
#scores = cross_val_score(LinearRegression(), X, Y, cv = RepeatedKFold(n_repeats = 1000))
# Aber eigentlich ist der Standardwert 10! - 100 oder 1000 bringen keine wirkliche Verbesserung
print(scores)
print("Durchschnitt der Scores: " + str(np.mean(scores)))
#Actung, das kann eine Minute dauern....
# Out:
# [0.83853717 0.85365039 0.84608778 0.85348786 0.85442426 0.85196435
#  0.84713935 0.84552094 0.85040528 0.85153219 0.8460171  0.85252753
#  0.84952796 0.85263598 0.84571967 0.85017626 0.84884748 0.85107939
#  0.84485421 0.85156375 0.84584117 0.84783648 0.85755694 0.84147682
#  0.85379701 0.8495516  0.85119232 0.84436857 0.84974955 0.85157193
#  0.8425044  0.8485393  0.85327976 0.84901093 0.85286367 0.84703498
#  0.85296018 0.84842351 0.85422614 0.84373396 0.85779274 0.84512214
#  0.8434904  0.85270794 0.84729888 0.84822691 0.84284828 0.85219737
#  0.85159411 0.85163537]
# Durchschnitt der Scores: 0.8492826448942856

# %%
X = df[["x", "y", "z"]].values
Y = df[["price"]].values

# %%
scores = cross_val_score(LinearRegression(), X, Y, cv = RepeatedKFold(n_repeats = 100))
#scores = cross_val_score(LinearRegression(), X, Y, cv = RepeatedKFold(n_repeats = 1000))
# Aber eigentlich ist der Standardwert 10! - 100 oder 1000 bringen keine wirkliche Verbesserung
print(scores)
print("Durchschnitt der Scores: " + str(np.mean(scores)))
# Out:
# [0.78764552 0.78875921 0.77528935 0.77880484 0.77426743 0.77977144
#  0.78187804 0.7798066  0.78215379 0.7848366  0.78058786 0.78332051
#  0.77412427 0.78750552 0.78274879 0.78924773 0.78106242 0.77776765
#  0.78138159 0.77587171 0.79227048 0.77808014 0.55893798 0.77261785
#  0.78302189 0.782513   0.77878443 0.78255497 0.78376317 0.55180417
#  0.77926152 0.78676673 0.77443545 0.77766103 0.78654474 0.78036766
#  0.78354238 0.76722213 0.78528961 0.78829183 0.7787576  0.78638194
#  0.77292219 0.78764259 0.77975343 0.78446499 0.78445192 0.77846507
#  0.78190876 0.77505472 0.78195528 0.78244514 0.78685975 0.78107072
#  0.77269095 0.77851008 0.77246971 0.78061376 0.7874959  0.78722025
#  0.78162672 0.78135636 0.78108273 0.78223196 0.77960456 0.78669653
#  0.78075632 0.7792601  0.77469002 0.78501408 0.78294724 0.78712521
